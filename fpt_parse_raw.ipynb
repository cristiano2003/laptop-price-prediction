# %%
from bs4 import BeautifulSoup as bs
import os
import sqlite3

def _parse_specs_detail(detail_specs_html_path: str) -> dict:
    output = {}
    try:
        with open(detail_specs_html_path, 'r', encoding='utf-8') as f:
            detail_specs_html = f.read()
        
        soup = bs(detail_specs_html, 'html.parser')
        
        modal_content = soup.find('div', {'class': 'c-modal__content'})
        
        rows = modal_content.find_all('div', {'class': 'c-modal__row'})
        
        for row in rows:
            st_table_title = row.find('div', {'class': 'st-table-title'}).text.strip()
            # print(f"==>> st_table_title: {st_table_title}")
            
            table = row.find('table')
            if table is None:
                continue
            
            ####################### Parse in detail #######################
            row_of_table = table.find_all('tr')
            
            if st_table_title == 'Bộ xử lý':
                for rows_in_table in row_of_table:
                    cols = rows_in_table.find_all('td')
                    # print(f"==>> cols: {cols}")
                    
                    prop = cols[0].text.strip()
                    value = cols[1].text.strip()
                    
                    if prop == 'Công nghệ CPU':
                        output['CPU brand modifier'] = value
                    elif prop == 'Loại CPU':
                        output['CPU generation'] = value
                    elif prop == 'Tốc độ tối đa':
                        output['CPU Speed (GHz)'] = value
                    elif prop == 'Hãng CPU':
                        output['CPU manufacturer'] = value
            elif st_table_title == 'RAM':
                for rows_in_table in row_of_table:
                    cols = rows_in_table.find_all('td')
                    # print(f"==>> cols: {cols}")
                    
                    prop = cols[0].text.strip()
                    value = cols[1].text.strip()
                    
                    if prop == 'Dung lượng RAM':
                        output['RAM (GB)'] = value
                    elif prop == 'Loại RAM':
                        output['RAM Type'] = value
                    elif prop == 'Tốc độ RAM':
                        output['Bus (MHz)'] = value
            elif st_table_title == 'Màn hình':
                for rows_in_table in row_of_table:
                    cols = rows_in_table.find_all('td')
                    # print(f"==>> cols: {cols}")
                    
                    prop = cols[0].text.strip()
                    value = cols[1].text.strip()
                    
                    if prop == 'Kích thước màn hình':
                        output['Screen Size (inch)'] = value
                    elif prop == 'Độ phân giải':
                        output['Screen Resolution'] = value
                    elif prop == 'Tần số quét':
                        output['Refresh Rate (Hz)'] = value
            elif st_table_title == 'Đồ họa':
                for rows_in_table in row_of_table:
                    cols = rows_in_table.find_all('td')
                    # print(f"==>> cols: {cols}")
                    
                    prop = cols[0].text.strip()
                    value = cols[1].text.strip()
                    
                    if prop == 'Hãng':
                        output['GPU manufacturer'] = value
            elif st_table_title == 'Thông tin pin & Sạc':
                for rows_in_table in row_of_table:
                    cols = rows_in_table.find_all('td')
                    # print(f"==>> cols: {cols}")
                    
                    prop = cols[0].text.strip()
                    value = cols[1].text.strip()
                    
                    if prop == 'Dung lượng pin':
                        output['Battery'] = value
                        
        return output
    except Exception as e:
        print(f"==>> Error: {e}")
        return None

def _parse_html(conn: sqlite3.Connection, raw_html_path: str, detail_specs_html_path: str) -> dict:
    output = {}

    try:
        print('Parsing HTML', raw_html_path)
        
        if not os.path.exists(raw_html_path) or not os.path.exists(detail_specs_html_path):
            return {
                'status': 'error',
                'message': 'File not found',
                'data': None
            }
        
        with open(raw_html_path, 'r', encoding='utf-8') as f:
            raw_html = f.read()
            
        raw_soup = bs(raw_html, 'html.parser')
        
        # Get the manufacturer
        manufacturer = conn.execute(f'''
                        select Manufacturer from fpt_fetch_results
                        where Raw_html_path = '{raw_html_path}'
                                    ''').fetchone()[0]
        output['Manufacturer'] = manufacturer

        # Get the price
        price = raw_soup.find('div', {'class': 'st-price-main'}).text.strip()
        output['Price (VND)'] = price
        
        # Go to summary specs
        thong_so_ky_thuat = raw_soup.find('div', {'class': 'card re-card st-card'})
        card_body = thong_so_ky_thuat.find('div', {'class': 'card-body'})
        tbody = card_body.find('tbody')
        
        for row in tbody.find_all('tr'):
            cols = row.find_all('td')
            
            prop = cols[0].text.strip()
            value = cols[1].text.strip()
            
            if prop == 'Trọng lượng':
                output['Weight (kg)'] = value
            if prop == 'Ổ cứng':
                output['Storage (GB)'] = value
        
        # Go to detail specs
        detail_specs = _parse_specs_detail(detail_specs_html_path)
        
        if detail_specs is not None:
            output.update(detail_specs)
            
        return output
    except Exception as e:
        return None

# %%
_parse_html(
    conn=sqlite3.connect('database/introds.db'),
    raw_html_path='data/fpt/raw_htmls/msi_36.html',
    detail_specs_html_path='data/fpt/detail_htmls/msi_36.html'
)
# Out:
# Parsing HTML data/fpt/raw_htmls/msi_36.html
# {'Manufacturer': 'msi',
#  'Price (VND)': '15.790.000₫',
#  'Storage (GB)': 'SSD 512 GB',
#  'Weight (kg)': '1.4 kg',
#  'CPU manufacturer': 'Intel',
#  'CPU brand modifier': 'Core i5',
#  'CPU generation': '1335U',
#  'CPU Speed (GHz)': '4.6 GHz',
#  'RAM (GB)': '8 GB',
#  'RAM Type': 'DDR4',
#  'Bus (MHz)': '3200 MHz',
#  'Screen Size (inch)': '14.0 inch',
#  'Screen Resolution': '1920 x 1080 Pixels',
#  'Refresh Rate (Hz)': '60 Hz',
#  'GPU manufacturer': 'Intel'}

# %%
conn = sqlite3.connect('database/introds.db')

rows = conn.execute('select Raw_html_path, Detail_specs_html_path from fpt_fetch_results').fetchall()

res = []

err = []

for row in rows:
    raw_html_path = row[0]
    detail_specs_html_path = row[1]
    
    output = _parse_html(conn, raw_html_path, detail_specs_html_path)
    
    if output is None:
        err.append(raw_html_path)
        continue
    
    print(f"==>> output: {output}")
    
    res.append(output)
# Out:
# Parsing HTML data/fpt/raw_htmls/asus_3.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '8.990.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.8 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 3', 'CPU generation': '7320U', 'CPU Speed (GHz)': '4.1 GHz', 'RAM (GB)': '8 GB', 'RAM Type': 'LPDDR5', 'Bus (MHz)': '5500 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_0.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '17.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.3 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '11400H', 'CPU Speed (GHz)': '4.5 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'NVIDIA', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_1.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '20.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.2 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '12500H', 'CPU Speed (GHz)': '4.5 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_2.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '13.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.3 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '7520U', 'CPU Speed (GHz)': '4.3 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'LPDDR5', 'Bus (MHz)': '5500 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'AMD'}
# Parsing HTML data/fpt/raw_htmls/asus_4.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '16.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.5 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '7530U', 'CPU Speed (GHz)': '4.30 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR4', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_7.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '15.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.7 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '7530U', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels Màn hình chính:', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '50 Wh'}
# Parsing HTML data/fpt/raw_htmls/asus_6.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '8.990.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.6 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i3', 'CPU generation': '1115G4', 'CPU Speed (GHz)': '4.1 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_0.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '17.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.3 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '11400H', 'CPU Speed (GHz)': '4.5 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'NVIDIA', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_0.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '17.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.3 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '11400H', 'CPU Speed (GHz)': '4.5 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'NVIDIA', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_3.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '8.990.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.8 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 3', 'CPU generation': '7320U', 'CPU Speed (GHz)': '4.1 GHz', 'RAM (GB)': '8 GB', 'RAM Type': 'LPDDR5', 'Bus (MHz)': '5500 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_6.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '8.990.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.6 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i3', 'CPU generation': '1115G4', 'CPU Speed (GHz)': '4.1 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_9.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '10.790.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.68 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i3', 'CPU generation': '1215U', 'CPU Speed (GHz)': '4.4 GHz', 'RAM (GB)': '8 GB', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '16.0 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_4.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '16.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.5 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '7530U', 'CPU Speed (GHz)': '4.30 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR4', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_2.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '13.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.3 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '7520U', 'CPU Speed (GHz)': '4.3 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'LPDDR5', 'Bus (MHz)': '5500 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'AMD'}
# Parsing HTML data/fpt/raw_htmls/asus_5.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '17.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.7 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '13500H', 'CPU Speed (GHz)': '4.7 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_7.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '15.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.7 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '7530U', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels Màn hình chính:', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '50 Wh'}
# Parsing HTML data/fpt/raw_htmls/asus_1.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '20.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.2 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '12500H', 'CPU Speed (GHz)': '4.5 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_8.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '16.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.6 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '13500H', 'CPU Speed (GHz)': '4.7 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '2880 x 1800 Pixels', 'Refresh Rate (Hz)': '90 Hz', 'GPU manufacturer': 'Intel', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_10.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '17.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.3 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '11400H', 'CPU Speed (GHz)': '4.5 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_11.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '25.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.2 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 7', 'CPU generation': '7735HS', 'CPU Speed (GHz)': '4.7 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'NVIDIA'}
# Parsing HTML data/fpt/raw_htmls/asus_12.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '16.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.7 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1335U', 'CPU Speed (GHz)': '4.6 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': 'FHD (1920 x 1080)', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '42 Wh'}
# Parsing HTML data/fpt/raw_htmls/asus_14.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '9.990.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.4 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i3', 'CPU generation': '1215U', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '1920 x 1080 Pixels Màn hình chính:', 'Refresh Rate (Hz)': '60  Màn hình chính: Hz', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_15.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '15.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.68 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1335U', 'CPU Speed (GHz)': '4.6 GHz', 'RAM (GB)': '8 GB', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '16 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_16.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '19.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.30 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '11800H', 'CPU Speed (GHz)': '4.60 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': 'FHD (1920 x 1080)', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'NVIDIA'}
# Parsing HTML data/fpt/raw_htmls/asus_17.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '23.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.5 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i9', 'CPU generation': '13900H', 'CPU Speed (GHz)': '5.4 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_13.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '26.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.2 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 7', 'CPU generation': '7735HS', 'CPU Speed (GHz)': '4.7 GHz', 'RAM (GB)': '8 GB', 'RAM Type': 'DDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'AMD'}
# Parsing HTML data/fpt/raw_htmls/asus_19.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '13.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.8 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 7', 'CPU generation': '5700U', 'CPU Speed (GHz)': '4.3 GHz', 'RAM (GB)': '8 GB', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': 'FHD (1920 x 1080)', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'AMD', 'Battery': '65 Wh'}
# Parsing HTML data/fpt/raw_htmls/asus_18.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '21.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.7 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1360P', 'CPU Speed (GHz)': '5 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_20.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '18.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '12450H', 'CPU Speed (GHz)': '4.4 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_21.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '23.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.39 g', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1340P', 'CPU Speed (GHz)': '4.6 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '2880 x 1800 Pixels', 'Refresh Rate (Hz)': '90 Hz', 'GPU manufacturer': 'Intel', 'Battery': '4 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_22.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '15.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.7 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '7530U', 'CPU Speed (GHz)': '4.3 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': 'FHD (1920 x 1080)', 'Refresh Rate (Hz)': '60 Hz', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_23.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '16.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.7 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '12500H', 'CPU Speed (GHz)': '4.5 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_24.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '28.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.2 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '12700H', 'CPU Speed (GHz)': '4.70 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_26.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '26.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.2 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 7', 'CPU generation': '7735HS', 'CPU Speed (GHz)': '4.7 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR5', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': 'FHD (1920 x 1080)', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'NVIDIA', 'Battery': '90 Wh'}
# Parsing HTML data/fpt/raw_htmls/asus_25.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '15.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.88 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 7', 'CPU generation': '7730U', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Screen Size (inch)': '16 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'AMD', 'Battery': '42 Wh'}
# Parsing HTML data/fpt/raw_htmls/asus_27.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '29.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.2 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '12700H', 'RAM (GB)': '16 GB', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels Màn hình chính:', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'NVIDIA', 'Battery': '90 Wh'}
# Parsing HTML data/fpt/raw_htmls/asus_29.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '14.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.7 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1240P', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_28.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '20.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.39 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1240P', 'CPU Speed (GHz)': '4.4 GHz', 'RAM (GB)': '8 GB', 'RAM Type': 'DDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '2880 x 1800 Pixels', 'Refresh Rate (Hz)': '90 Hz', 'GPU manufacturer': 'Intel', 'Battery': '4 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_30.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '25.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.5 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1340P', 'CPU Speed (GHz)': '4.6 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'LPDDR5', 'Bus (MHz)': '5500 MHz', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '2880 x 1800 Pixels', 'Refresh Rate (Hz)': '90 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_32.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '30.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.5 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1360P', 'CPU Speed (GHz)': '5.00 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '2880 x 1800 Pixels Màn hình chính:', 'Refresh Rate (Hz)': '90 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_31.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '9.590.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.8 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i3', 'CPU generation': '1115G4', 'CPU Speed (GHz)': '4.1 GHz', 'RAM (GB)': '8 GB (2 thanh 4 GB)', 'RAM Type': 'DDR4', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': 'FHD (1920 x 1080)', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_36.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '27.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.39 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1360P', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR5', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '2880 x 1800 Pixels', 'Refresh Rate (Hz)': '90 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_35.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '37.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '3.82 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '13650HX', 'CPU Speed (GHz)': '4.9 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '16.0 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '165 Hz', 'GPU manufacturer': 'Intel', 'Battery': '90 Wh'}
# Parsing HTML data/fpt/raw_htmls/asus_34.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '16.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.3 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '4600H', 'CPU Speed (GHz)': '4 GHz', 'RAM (GB)': '8 GB', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '144 Hz'}
# Parsing HTML data/fpt/raw_htmls/asus_38.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '23.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.4 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i9', 'CPU generation': '13900H', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '2880 x 1800 Pixels', 'Refresh Rate (Hz)': '90 Hz', 'GPU manufacturer': 'Intel', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_33.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '27.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.2 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '12700H', 'CPU Speed (GHz)': '4.7 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'NVIDIA'}
# Parsing HTML data/fpt/raw_htmls/asus_39.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '27.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.2 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '12700H', 'CPU Speed (GHz)': '4.70 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6  Chính: inch', 'Screen Resolution': '1920 x 1080 Pixels Màn hình chính:', 'Refresh Rate (Hz)': '144  Màn hình chính: Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_37.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '30.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.8 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '13500H', 'CPU Speed (GHz)': '4.7 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR5', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '2880 x 1620 Pixels', 'Refresh Rate (Hz)': '120 Hz'}
# Parsing HTML data/fpt/raw_htmls/asus_40.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '33.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.8 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i9', 'CPU generation': '13900H', 'CPU Speed (GHz)': '5.4 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR5', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '2880 x 1620 Pixels', 'Refresh Rate (Hz)': '120 Hz'}
# Parsing HTML data/fpt/raw_htmls/asus_41.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '27.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.4 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i9', 'CPU generation': '13900H', 'CPU Speed (GHz)': '5.6 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '2880 x 1800 Pixels', 'Refresh Rate (Hz)': '90 Hz', 'GPU manufacturer': 'NVIDIA', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_44.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '17.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1600 g', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '13500H', 'CPU Speed (GHz)': '4.7 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '2880 x 1800 Pixels', 'Refresh Rate (Hz)': '90 Hz', 'GPU manufacturer': 'Intel', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/asus_43.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '27.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.2 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Ultra 5 Meteor Lake', 'CPU generation': '125H', 'CPU Speed (GHz)': '4.5 GHz', 'RAM (GB)': '16 GB (1 thanh 16 GB)', 'RAM Type': 'LPDDR5X', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '2880 x 1800 Pixels', 'Refresh Rate (Hz)': '120', 'GPU manufacturer': 'Intel', 'Battery': '75 Wh'}
# Parsing HTML data/fpt/raw_htmls/asus_45.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '10.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.4 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i3', 'CPU generation': '1215U', 'CPU Speed (GHz)': '4.4 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Screen Size (inch)': '14 inch', 'Screen Resolution': 'FHD (1920 x 1080)', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '42 Wh'}
# Parsing HTML data/fpt/raw_htmls/asus_42.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '38.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '13620H', 'CPU Speed (GHz)': '4.9 GHz', 'RAM (GB)': '16 GB (1 thanh 16 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '16.0 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '165 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/asus_46.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '38.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.20 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i9', 'CPU generation': '13900H', 'CPU Speed (GHz)': '5.4 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '144 Hz'}
# Parsing HTML data/fpt/raw_htmls/asus_47.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '28.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.2 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '7535HS', 'CPU Speed (GHz)': '4.5 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR5', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': 'FHD (1920 x 1080)', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'NVIDIA', 'Battery': '90 Wh'}
# Parsing HTML data/fpt/raw_htmls/asus_48.html
# ==>> output: {'Manufacturer': 'asus', 'Price (VND)': '23.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.7 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i9', 'CPU generation': '13900H', 'CPU Speed (GHz)': '5.4 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/hp_1.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '10.990.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.36 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '7520U', 'RAM (GB)': '8 GB', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'AMD', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_0.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '13.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.4 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '7520U', 'CPU Speed (GHz)': '4.3 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'LPDDR5', 'Bus (MHz)': '5500 MHz', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'AMD', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_2.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '15.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.41 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1235U', 'CPU Speed (GHz)': '4.4 GHz', 'RAM (GB)': '8 GB (2 thanh 4 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '43 Wh'}
# Parsing HTML data/fpt/raw_htmls/hp_3.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '8.990.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.4 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 3', 'CPU generation': '7320U', 'CPU Speed (GHz)': '4.1 GHz', 'RAM (GB)': '8 GB', 'RAM Type': 'LPDDR5', 'Bus (MHz)': '6400 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_4.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '11.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.4 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '7520U', 'CPU Speed (GHz)': '4.3 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'LPDDR5', 'Bus (MHz)': '5500 MHz', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'AMD', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_5.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '9.190.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.7 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i3', 'CPU generation': '1115G4', 'CPU Speed (GHz)': '4.1 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '41 mAh'}
# Parsing HTML data/fpt/raw_htmls/hp_6.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '17.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.41 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1235U', 'CPU Speed (GHz)': '4.4 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '43 Wh'}
# Parsing HTML data/fpt/raw_htmls/hp_7.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '9.190.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.7 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i3', 'CPU generation': '1115G4', 'CPU Speed (GHz)': '4.1 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '41 mAh'}
# Parsing HTML data/fpt/raw_htmls/hp_8.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '10.490.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.47 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '5625U', 'CPU Speed (GHz)': '4.3 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'AMD', 'Battery': '41 Wh'}
# Parsing HTML data/fpt/raw_htmls/hp_9.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '19.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.59 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1355U', 'RAM (GB)': '16 GB', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_11.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '18.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.68 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1335U', 'CPU Speed (GHz)': '4.60 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': 'FHD (1920 x 1080)', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_10.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '16.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.36 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1335U', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR4', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_12.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '21.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.68 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1335U', 'CPU Speed (GHz)': '5.00 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': 'FHD (1920 x 1080)', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_14.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '13.490.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.69 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1235U', 'CPU Speed (GHz)': '4.4 GHz', 'RAM (GB)': '8 GB (2 thanh 4 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_18.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '23.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.38 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1360P', 'RAM (GB)': '16 GB', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '51 Wh'}
# Parsing HTML data/fpt/raw_htmls/hp_19.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '20.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.4 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 7', 'CPU generation': '6800H', 'CPU Speed (GHz)': '4.70 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '16.1 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'NVIDIA'}
# Parsing HTML data/fpt/raw_htmls/hp_16.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '19.790.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 7', 'CPU generation': '7735U', 'CPU Speed (GHz)': '4.70 GHz', 'RAM (GB)': '16 GB (1 thanh 16 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '13.3 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'GPU manufacturer': 'AMD', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_15.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '20.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.38 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1340P', 'RAM (GB)': '16 GB', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'Battery': '51 Wh'}
# Parsing HTML data/fpt/raw_htmls/hp_20.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '20.590.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.41 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1255U', 'CPU Speed (GHz)': '4.4 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '43 Wh'}
# Parsing HTML data/fpt/raw_htmls/hp_22.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '14.690.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.71 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1240P', 'RAM (GB)': '8 GB (2 thanh 4 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_21.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '19.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.41 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1255U', 'RAM (GB)': '8 GB', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'Battery': '43 Wh'}
# Parsing HTML data/fpt/raw_htmls/hp_17.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '16.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.69 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1335U', 'CPU Speed (GHz)': '4.60 GHz', 'RAM (GB)': '8 GB (2 thanh 4 GB)', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': 'FHD (1920 x 1080)', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_13.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '16.090.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.72 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1240P', 'RAM (GB)': '8 GB (2 thanh 4 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15,6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_24.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '24.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.34 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1250U', 'RAM (GB)': '8 GB', 'Screen Size (inch)': '13.3 inch', 'Screen Resolution': '2880 x 1800 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'Battery': '66 Wh'}
# Parsing HTML data/fpt/raw_htmls/hp_25.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '16.690.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.69 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1255U', 'CPU Speed (GHz)': '4.4 GHz', 'RAM (GB)': '8 GB (2 thanh 4 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'Battery': '41 Wh'}
# Parsing HTML data/fpt/raw_htmls/hp_27.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '17.890.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.4 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '6600H', 'CPU Speed (GHz)': '4.5 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '16.1 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'NVIDIA'}
# Parsing HTML data/fpt/raw_htmls/hp_23.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '16.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.7 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1235U', 'CPU Speed (GHz)': '4.40 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '41'}
# Parsing HTML data/fpt/raw_htmls/hp_30.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '14.590.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.41 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1235U', 'CPU Speed (GHz)': '4.4 GHz', 'RAM (GB)': '8 GB (2 thanh 4 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_29.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '9.190.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.35 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i3', 'CPU generation': '1115G4', 'CPU Speed (GHz)': '4.1 GHz', 'RAM (GB)': '8 GB (2 thanh 8 GB)', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'GPU manufacturer': 'Intel', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_31.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '25.590.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.42 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1355U', 'RAM (GB)': '16 GB', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'Battery': '51 Wh'}
# Parsing HTML data/fpt/raw_htmls/lenovo_0.html
# ==>> output: {'Manufacturer': 'lenovo', 'Price (VND)': '10.290.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.58 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '5500U', 'CPU Speed (GHz)': '4.00 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'AMD', 'Battery': '42 Wh'}
# Parsing HTML data/fpt/raw_htmls/hp_26.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '24.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.31 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '7640HS', 'RAM (GB)': '16 GB', 'Screen Size (inch)': '16.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'NVIDIA', 'Battery': '4 Cell'}
# Parsing HTML data/fpt/raw_htmls/hp_28.html
# ==>> output: {'Manufacturer': 'hp', 'Price (VND)': '16.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.71 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1235U', 'CPU Speed (GHz)': '4.4 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/lenovo_1.html
# ==>> output: {'Manufacturer': 'lenovo', 'Price (VND)': '13.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.65 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1155G7', 'CPU Speed (GHz)': '4.5 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/lenovo_2.html
# ==>> output: {'Manufacturer': 'lenovo', 'Price (VND)': '13.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.37 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '12450H', 'CPU Speed (GHz)': '4.40 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/lenovo_3.html
# ==>> output: {'Manufacturer': 'lenovo', 'Price (VND)': '12.690.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.65 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '12500H', 'CPU Speed (GHz)': '4.5 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '38 Wh'}
# Parsing HTML data/fpt/raw_htmls/lenovo_6.html
# ==>> output: {'Manufacturer': 'lenovo', 'Price (VND)': '17.290.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.46 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '13500H', 'CPU Speed (GHz)': '4.7 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR5', 'Bus (MHz)': '5200 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '3 Cell'}
# Parsing HTML data/fpt/raw_htmls/lenovo_10.html
# ==>> output: {'Manufacturer': 'lenovo', 'Price (VND)': '24.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.35 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '13700H', 'CPU Speed (GHz)': '5 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR5', 'Bus (MHz)': '5200 MHz', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '65 Wh'}
# Parsing HTML data/fpt/raw_htmls/lenovo_11.html
# ==>> output: {'Manufacturer': 'lenovo', 'Price (VND)': '10.190.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.65 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1155G7', 'CPU Speed (GHz)': '4.5 GHz', 'RAM (GB)': '8 GB', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/lenovo_12.html
# ==>> output: {'Manufacturer': 'lenovo', 'Price (VND)': '22.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.57 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1145G7', 'CPU Speed (GHz)': '4.4 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR4', 'Bus (MHz)': '4266 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '57 Wh'}
# Parsing HTML data/fpt/raw_htmls/lenovo_7.html
# ...
# Parsing HTML data/fpt/raw_htmls/msi_21.html
# ==>> output: {'Manufacturer': 'msi', 'Price (VND)': '16.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.4 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1335U', 'CPU Speed (GHz)': '4.6 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/msi_23.html
# ==>> output: {'Manufacturer': 'msi', 'Price (VND)': '47.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.8 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '13700H', 'CPU Speed (GHz)': '5.00 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR5', 'Bus (MHz)': '5200 MHz', 'Screen Size (inch)': '17.3 inch', 'Screen Resolution': '2560 x 1440 Pixels', 'Refresh Rate (Hz)': '240 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/msi_24.html
# ==>> output: {'Manufacturer': 'msi', 'Price (VND)': '59.990.000₫', 'Storage (GB)': 'SSD 2 TB', 'Weight (kg)': '2.7 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '13700HX', 'CPU Speed (GHz)': '5.00 GHz', 'RAM (GB)': '32 GB (2 thanh 16 GB)', 'RAM Type': 'DDR5', 'Bus (MHz)': '5600 MHz', 'Screen Size (inch)': '16.0 inch', 'Screen Resolution': '2560 x 1600 Pixels', 'Refresh Rate (Hz)': '240 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/msi_26.html
# ==>> output: {'Manufacturer': 'msi', 'Price (VND)': '89.990.000₫', 'Storage (GB)': 'SSD 2 TB', 'Weight (kg)': '2.9 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i9', 'CPU generation': '12900HX', 'CPU Speed (GHz)': '5 GHz', 'RAM (GB)': '64 GB', 'RAM Type': 'DDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '17.3 inch', 'Screen Resolution': '3840 x 2160 Pixels', 'Refresh Rate (Hz)': '120 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/msi_27.html
# ==>> output: {'Manufacturer': 'msi', 'Price (VND)': '65.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2.8 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i9', 'CPU generation': '12900H', 'CPU Speed (GHz)': '5 GHz', 'RAM (GB)': '32 GB', 'RAM Type': 'DDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '17.3 inch', 'Screen Resolution': '2560 x 1440 Pixels', 'Refresh Rate (Hz)': '240 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/msi_28.html
# ==>> output: {'Manufacturer': 'msi', 'Price (VND)': '17.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.98 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '12450H', 'CPU Speed (GHz)': '4.4 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR5', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': 'FHD (1920 x 1080)', 'Refresh Rate (Hz)': '144 Hz', 'GPU manufacturer': 'NVIDIA'}
# Parsing HTML data/fpt/raw_htmls/msi_32.html
# Parsing HTML data/fpt/raw_htmls/msi_22.html
# ==>> output: {'Manufacturer': 'msi', 'Price (VND)': '49.990.000₫', 'Storage (GB)': 'SSD 2 TB', 'Weight (kg)': '2.7 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '13700HX', 'CPU Speed (GHz)': '5 GHz', 'RAM (GB)': '16 MB', 'RAM Type': 'DDR5', 'Bus (MHz)': '5600 MHz', 'Screen Size (inch)': '16.0 inch', 'Screen Resolution': '2560 x 1600 Pixels', 'Refresh Rate (Hz)': '240 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/msi_29.html
# ==>> output: {'Manufacturer': 'msi', 'Price (VND)': '68.990.000₫', 'Storage (GB)': 'SSD 2 TB', 'Weight (kg)': '2.35 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '13700HX', 'CPU Speed (GHz)': '5.00 GHz', 'RAM (GB)': '32 GB (2 thanh 16 GB)', 'RAM Type': 'DDR5', 'Bus (MHz)': '5600 MHz', 'Screen Size (inch)': '16.0 inch', 'Screen Resolution': '2560 x 1600 Pixels', 'Refresh Rate (Hz)': '120 Hz', 'GPU manufacturer': 'NVIDIA', 'Battery': '90 Wh'}
# Parsing HTML data/fpt/raw_htmls/msi_30.html
# ==>> output: {'Manufacturer': 'msi', 'Price (VND)': '60.990.000₫', 'Storage (GB)': 'SSD 1 TB', 'Weight (kg)': '2.2 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '12700H', 'CPU Speed (GHz)': '4.7 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '16.0 inch', 'Screen Resolution': '2560 x 1600 Pixels', 'Refresh Rate (Hz)': '120 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/msi_31.html
# ==>> output: {'Manufacturer': 'msi', 'Price (VND)': '19.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.4 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1355U', 'CPU Speed (GHz)': '5 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/msi_25.html
# ==>> output: {'Manufacturer': 'msi', 'Price (VND)': '10.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.4 kg', 'CPU manufacturer': 'AMD', 'CPU brand modifier': 'Ryzen 5', 'CPU generation': '5625U', 'CPU Speed (GHz)': '4.3 GHz', 'RAM (GB)': '8 GB', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15,6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'AMD', 'Battery': '39.3 Wh'}
# Parsing HTML data/fpt/raw_htmls/msi_33.html
# ==>> output: {'Manufacturer': 'msi', 'Price (VND)': '16.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.4 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1335U', 'CPU Speed (GHz)': '4.6 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/msi_34.html
# ==>> output: {'Manufacturer': 'msi', 'Price (VND)': '16.190.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.7 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1255U', 'CPU Speed (GHz)': '4.70 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/msi_35.html
# ==>> output: {'Manufacturer': 'msi', 'Price (VND)': '15.790.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.4 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1335U', 'CPU Speed (GHz)': '4.6 GHz', 'RAM (GB)': '8 GB', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/msi_36.html
# ==>> output: {'Manufacturer': 'msi', 'Price (VND)': '15.790.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.4 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1335U', 'CPU Speed (GHz)': '4.6 GHz', 'RAM (GB)': '8 GB', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/dell_0.html
# ==>> output: {'Manufacturer': 'dell', 'Price (VND)': '14.990.000₫', 'Storage (GB)': 'SSD 256 GB', 'Weight (kg)': '1.9 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1235U', 'CPU Speed (GHz)': '4.4 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '2666 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '120 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/dell_1.html
# ==>> output: {'Manufacturer': 'dell', 'Price (VND)': '20.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.66 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1335U', 'CPU Speed (GHz)': '4.6 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '2666 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': 'FHD (1920 x 1080)', 'Refresh Rate (Hz)': '120 Hz', 'GPU manufacturer': 'NVIDIA'}
# Parsing HTML data/fpt/raw_htmls/dell_2.html
# ==>> output: {'Manufacturer': 'dell', 'Price (VND)': '24.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.65 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1355U', 'CPU Speed (GHz)': '5.00 GHz', 'RAM (GB)': '16 GB (2 thanh 8 GB)', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '120 Hz'}
# Parsing HTML data/fpt/raw_htmls/dell_4.html
# ==>> output: {'Manufacturer': 'dell', 'Price (VND)': '23.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.74 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1355U', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR4', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '120 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/dell_3.html
# ==>> output: {'Manufacturer': 'dell', 'Price (VND)': '22.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.62 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1335U', 'CPU Speed (GHz)': '4.60 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'LPDDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1200 Pixels Màn hình chính:', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/dell_5.html
# ==>> output: {'Manufacturer': 'dell', 'Price (VND)': '19.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.97 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1240P', 'CPU Speed (GHz)': '4.50 GHz', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Screen Size (inch)': '16.0 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'Battery': '3420 mAh'}
# Parsing HTML data/fpt/raw_htmls/dell_6.html
# ==>> output: {'Manufacturer': 'dell', 'Price (VND)': '19.090.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.7 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1255U', 'CPU Speed (GHz)': '4.40 GHz', 'RAM (GB)': '8 GB', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '120 Hz', 'Battery': '54 Wh'}
# Parsing HTML data/fpt/raw_htmls/dell_7.html
# ==>> output: {'Manufacturer': 'dell', 'Price (VND)': '22.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.85 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1240P', 'CPU Speed (GHz)': '4.4 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'DDR4', 'Bus (MHz)': '3200 MHz', 'Screen Size (inch)': '16.0 inch', 'Screen Resolution': '1200 x 1920 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'NVIDIA', 'Battery': '54 Wh'}
# Parsing HTML data/fpt/raw_htmls/dell_8.html
# ==>> output: {'Manufacturer': 'dell', 'Price (VND)': '32.490.000₫', 'Storage (GB)': 'SSD 1 TB', 'Weight (kg)': '1.78 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1360P', 'RAM (GB)': '16 GB (1 thanh 16 GB)', 'RAM Type': 'LPDDR5', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '2560 x 1600 Pixels', 'Refresh Rate (Hz)': '120 Hz'}
# Parsing HTML data/fpt/raw_htmls/dell_9.html
# ==>> output: {'Manufacturer': 'dell', 'Price (VND)': '30.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.94 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1360P', 'CPU Speed (GHz)': '5 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'LPDDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '60 Hz'}
# Parsing HTML data/fpt/raw_htmls/dell_10.html
# ==>> output: {'Manufacturer': 'dell', 'Price (VND)': '25.690.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.9 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1335U', 'CPU Speed (GHz)': '4.6 GHz', 'RAM (GB)': '16 GB', 'RAM Type': 'LPDDR5', 'Bus (MHz)': '4800 MHz', 'Screen Size (inch)': '16 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel'}
# Parsing HTML data/fpt/raw_htmls/dell_11.html
# ==>> output: {'Manufacturer': 'dell', 'Price (VND)': '21.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.66 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1355U', 'CPU Speed (GHz)': '5.00 GHz', 'RAM (GB)': '8 GB', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1080 Pixels', 'Refresh Rate (Hz)': '120 Hz', 'GPU manufacturer': 'Intel', 'Battery': '54 Wh'}
# Parsing HTML data/fpt/raw_htmls/dell_12.html
# ==>> output: {'Manufacturer': 'dell', 'Price (VND)': '18.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.63 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1335U', 'RAM (GB)': '8 GB (1 thanh 8 GB)', 'RAM Type': 'DDR4', 'Screen Size (inch)': '15.6 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '120 Hz'}
# Parsing HTML data/fpt/raw_htmls/lg_2.html
# ==>> output: {'Manufacturer': 'lg', 'Price (VND)': '41.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '2 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1360P', 'CPU Speed (GHz)': '4.6 GHz', 'RAM (GB)': '16 GB (1 thanh 16 GB)', 'RAM Type': 'DDR5', 'Bus (MHz)': '6000 MHz', 'Screen Size (inch)': '16.0 inch', 'Screen Resolution': '2560 x 1600 Pixels', 'Refresh Rate (Hz)': '120 Hz', 'GPU manufacturer': 'Intel', 'Battery': '80 Wh'}
# Parsing HTML data/fpt/raw_htmls/lg_1.html
# ==>> output: {'Manufacturer': 'lg', 'Price (VND)': '31.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.25 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1340P', 'RAM (GB)': '16 GB', 'RAM Type': 'LPDDR5', 'Bus (MHz)': '5200 MHz', 'Screen Size (inch)': '14.0 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'Intel', 'Battery': '72 Wh'}
# Parsing HTML data/fpt/raw_htmls/lg_0.html
# ==>> output: {'Manufacturer': 'lg', 'Price (VND)': '33.990.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1360P', 'RAM (GB)': '16 GB', 'Screen Size (inch)': '14 inch', 'Screen Resolution': '1920 x 1200 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'Battery': '72 Wh'}
# Parsing HTML data/fpt/raw_htmls/lg_3.html
# ==>> output: {'Manufacturer': 'lg', 'Price (VND)': '44.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.29 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i7', 'CPU generation': '1360P', 'RAM (GB)': '16 GB', 'RAM Type': 'LPDDR5', 'Bus (MHz)': '6000 MHz', 'Screen Size (inch)': '16.0 inch', 'Screen Resolution': '2560 x 1600 Pixels', 'Refresh Rate (Hz)': '60 Hz', 'GPU manufacturer': 'NVIDIA', 'Battery': '90 Wh'}
# Parsing HTML data/fpt/raw_htmls/lg_4.html
# ==>> output: {'Manufacturer': 'lg', 'Price (VND)': '34.490.000₫', 'Storage (GB)': 'SSD 512 GB', 'Weight (kg)': '1.5 kg', 'CPU manufacturer': 'Intel', 'CPU brand modifier': 'Core i5', 'CPU generation': '1340P', 'CPU Speed (GHz)': '4.6 GHz', 'RAM (GB)': '16 GB (1 thanh 16 GB)', 'RAM Type': 'DDR5', 'Bus (MHz)': '6000 MHz', 'Screen Size (inch)': '14.0  Chính: inch', 'Screen Resolution': '2880 x 1800 Pixels', 'Refresh Rate (Hz)': '90 Hz', 'GPU manufacturer': 'Intel'}

# %%
import json

with open('data/fpt/parse_results.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(res, ensure_ascii=False, indent=4))

# %%
len(res)
# Out:
# 207

# %%
import re 

abc = '16 GB (2 x 8 GB) DDR4 3200 MHz'

# -> 1920 x 1080

re.findall(r'\d+ GB', abc)
# Out:
# ['16 GB', '8 GB']
